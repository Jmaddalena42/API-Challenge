# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import csv


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #lat, lon = lat_lng
    #if city not in cities:
    #   cities.append(citipy.nearest_city(lat_lng[0], lat_lng[1])
 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#print(lat_lngs)
#list(zip(lat_lngs))
#type(lat_lngs)
# Out:
# 599

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="


#url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + api_key 
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 



#complete_url = url + "appid=" + api_key + units + "&q=" + city_name

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up lists to hold reponse info
# Create a list to store the weather data for each city
city_names = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = []
# Loop through the list of cities and perform a request for data on each

print("Beginning Data Retrieval")
print("---------------------------------")

city_num = 1

for city in cities:
    response = requests.get(query_url + city).json()
    
    if response ["cod"] == '404':
        print("City Not Found. Skipping...")
    else:    
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record {city_num} | {city}")
        city_num += 1
        
print("---------------------------------")
print("Data Retrieval Complete")
print("---------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Processing Record 1 | penzance
# Processing Record 2 | evensk
# Processing Record 3 | port alfred
# Processing Record 4 | chincha alta
# Processing Record 5 | borcea
# Processing Record 6 | laguna
# Processing Record 7 | ushuaia
# Processing Record 8 | port blair
# Processing Record 9 | clyde river
# Processing Record 10 | katherine
# Processing Record 11 | jamestown
# Processing Record 12 | provideniya
# Processing Record 13 | vao
# Processing Record 14 | albany
# Processing Record 15 | yerbogachen
# Processing Record 16 | kendari
# Processing Record 17 | barrow
# Processing Record 18 | atuona
# City Not Found. Skipping...
# Processing Record 19 | victoria
# Processing Record 20 | jawhar
# Processing Record 21 | avarua
# Processing Record 22 | mount isa
# Processing Record 23 | kaitangata
# Processing Record 24 | punta arenas
# Processing Record 25 | sohag
# Processing Record 26 | rikitea
# Processing Record 27 | souillac
# Processing Record 28 | seabra
# Processing Record 29 | zhigansk
# City Not Found. Skipping...
# Processing Record 30 | sao filipe
# Processing Record 31 | bethel
# Processing Record 32 | biak
# City Not Found. Skipping...
# Processing Record 33 | pimentel
# Processing Record 34 | namibe
# Processing Record 35 | mount gambier
# Processing Record 36 | kapaa
# Processing Record 37 | saint george
# Processing Record 38 | rio grande
# Processing Record 39 | yellowknife
# Processing Record 40 | muroto
# Processing Record 41 | lebu
# Processing Record 42 | mataura
# Processing Record 43 | hermanus
# Processing Record 44 | necochea
# Processing Record 45 | butaritari
# Processing Record 46 | santa rosa
# City Not Found. Skipping...
# Processing Record 47 | saskylakh
# Processing Record 48 | kitimat
# Processing Record 49 | carnarvon
# City Not Found. Skipping...
# Processing Record 50 | cidreira
# Processing Record 51 | harper
# Processing Record 52 | tasiilaq
# Processing Record 53 | bonavista
# Processing Record 54 | vaini
# Processing Record 55 | pilar
# Processing Record 56 | lopatino
# Processing Record 57 | klaksvik
# Processing Record 58 | paamiut
# Processing Record 59 | busselton
# Processing Record 60 | yar-sale
# Processing Record 61 | arraial do cabo
# Processing Record 62 | paramonga
# City Not Found. Skipping...
# Processing Record 63 | bima
# City Not Found. Skipping...
# Processing Record 64 | margate
# Processing Record 65 | torbay
# Processing Record 66 | bredasdorp
# Processing Record 67 | lompoc
# Processing Record 68 | berdigestyakh
# Processing Record 69 | chuy
# Processing Record 70 | hobyo
# City Not Found. Skipping...
# Processing Record 71 | kodiak
# City Not Found. Skipping...
# Processing Record 72 | altay
# Processing Record 73 | mindyak
# Processing Record 74 | gotsu
# Processing Record 75 | flin flon
# City Not Found. Skipping...
# City Not Found. Skipping...
# Processing Record 76 | qaanaaq
# Processing Record 77 | ngunguru
# Processing Record 78 | airai
# Processing Record 79 | quincy
# Processing Record 80 | catalina
# Processing Record 81 | vanimo
# Processing Record 82 | kimbe
# Processing Record 83 | bambous virieux
# Processing Record 84 | cape town
# Processing Record 85 | arman
# Processing Record 86 | port hardy
# Processing Record 87 | povazska bystrica
# Processing Record 88 | constitucion
# Processing Record 89 | cedar city
# Processing Record 90 | thinadhoo
# Processing Record 91 | bluff
# Processing Record 92 | araouane
# Processing Record 93 | dubbo
# Processing Record 94 | lourdes
# Processing Record 95 | kruisfontein
# Processing Record 96 | hobart
# Processing Record 97 | fairbanks
# Processing Record 98 | torbeyevo
# Processing Record 99 | angouleme
# Processing Record 100 | georgetown
# Processing Record 101 | russell
# Processing Record 102 | lima
# Processing Record 103 | luderitz
# Processing Record 104 | male
# Processing Record 105 | richards bay
# Processing Record 106 | liepaja
# Processing Record 107 | raton
# Processing Record 108 | iqaluit
# Processing Record 109 | port hedland
# Processing Record 110 | bambanglipuro
# Processing Record 111 | petropavlovskaya
# Processing Record 112 | new norfolk
# Processing Record 113 | rabupura
# Processing Record 114 | mar del plata
# City Not Found. Skipping...
# Processing Record 115 | rocha
# Processing Record 116 | guerrero negro
# Processing Record 117 | fortuna
# Processing Record 118 | pevek
# Processing Record 119 | los llanos de aridane
# City Not Found. Skipping...
# Processing Record 120 | vardo
# Processing Record 121 | yulara
# Processing Record 122 | tiksi
# City Not Found. Skipping...
# Processing Record 123 | haines junction
# City Not Found. Skipping...
# Processing Record 124 | dunedin
# Processing Record 125 | geraldton
# Processing Record 126 | denpasar
# Processing Record 127 | oranjestad
# Processing Record 128 | port elizabeth
# Processing Record 129 | zeya
# Processing Record 130 | coihaique
# Processing Record 131 | ngaoundere
# City Not Found. Skipping...
# Processing Record 132 | ayagoz
# Processing Record 133 | touros
# Processing Record 134 | nikolskoye
# Processing Record 135 | strezhevoy
# City Not Found. Skipping...
# Processing Record 136 | bermeo
# City Not Found. Skipping...
# Processing Record 137 | thompson
# Processing Record 138 | itacare
# Processing Record 139 | ust-tsilma
# Processing Record 140 | paidha
# Processing Record 141 | itoman
# Processing Record 142 | mizan teferi
# City Not Found. Skipping...
# Processing Record 143 | half moon bay
# Processing Record 144 | castro
# Processing Record 145 | mathathane
# Processing Record 146 | nanortalik
# Processing Record 147 | mahebourg
# Processing Record 148 | barranca
# Processing Record 149 | pachino
# Processing Record 150 | aklavik
# City Not Found. Skipping...
# City Not Found. Skipping...
# City Not Found. Skipping...
# Processing Record 151 | padang
# Processing Record 152 | teya
# Processing Record 153 | harlingen
# Processing Record 154 | lanigan
# Processing Record 155 | srednekolymsk
# City Not Found. Skipping...
# Processing Record 156 | dikson
# Processing Record 157 | nouadhibou
# Processing Record 158 | doka
# Processing Record 159 | hunsur
# Processing Record 160 | ostrovnoy
# Processing Record 161 | abha
# Processing Record 162 | ouadda
# Processing Record 163 | kununurra
# City Not Found. Skipping...
# Processing Record 164 | sawakin
# Processing Record 165 | trat
# Processing Record 166 | mayo
# Processing Record 167 | karratha
# Processing Record 168 | kattivakkam
# Processing Record 169 | wattegama
# Processing Record 170 | plateros
# Processing Record 171 | cherskiy
# Processing Record 172 | berlevag
# Processing Record 173 | belmonte
# Processing Record 174 | hay river
# Processing Record 175 | naze
# Processing Record 176 | mbekenyera
# Processing Record 177 | teahupoo
# Processing Record 178 | faya
# Processing Record 179 | ribeira grande
# Processing Record 180 | batticaloa
# Processing Record 181 | bonoua
# City Not Found. Skipping...
# Processing Record 182 | leningradskiy
# Processing Record 183 | gat
# Processing Record 184 | bantilan
# Processing Record 185 | sitka
# Processing Record 186 | champerico
# Processing Record 187 | mackay
# Processing Record 188 | beloha
# City Not Found. Skipping...
# Processing Record 189 | alofi
# Processing Record 190 | ljungby
# Processing Record 191 | aleksandrovsk-sakhalinskiy
# Processing Record 192 | tabory
# Processing Record 193 | hithadhoo
# Processing Record 194 | oktyabrskiy
# City Not Found. Skipping...
# Processing Record 195 | santa cruz de la palma
# Processing Record 196 | huadian
# City Not Found. Skipping...
# Processing Record 197 | bilma
# Processing Record 198 | terrace
# Processing Record 199 | mikuni
# Processing Record 200 | puerto ayora
# Processing Record 201 | tautira
# City Not Found. Skipping...
# Processing Record 202 | pangnirtung
# Processing Record 203 | zhezkazgan
# Processing Record 204 | yarada
# Processing Record 205 | tuktoyaktuk
# City Not Found. Skipping...
# Processing Record 206 | khartoum
# Processing Record 207 | ayorou
# Processing Record 208 | saint-philippe
# Processing Record 209 | chokurdakh
# Processing Record 210 | uruzgan
# Processing Record 211 | lahij
# Processing Record 212 | khatanga
# City Not Found. Skipping...
# Processing Record 213 | soyo
# Processing Record 214 | mehamn
# Processing Record 215 | pringsewu
# Processing Record 216 | kaseda
# City Not Found. Skipping...
# Processing Record 217 | onokhoy
# Processing Record 218 | sao joao da barra
# Processing Record 219 | ongandjera
# City Not Found. Skipping...
# City Not Found. Skipping...
# Processing Record 220 | olinda
# Processing Record 221 | placido de castro
# Processing Record 222 | santiago
# Processing Record 223 | juan lacaze
# Processing Record 224 | san patricio
# City Not Found. Skipping...
# Processing Record 225 | grindavik
# Processing Record 226 | picos
# Processing Record 227 | valavanur
# Processing Record 228 | lasa
# Processing Record 229 | konya
# Processing Record 230 | kenema
# Processing Record 231 | tuatapere
# Processing Record 232 | baykit
# Processing Record 233 | mastic beach
# Processing Record 234 | san cristobal
# Processing Record 235 | east london
# Processing Record 236 | clermont
# Processing Record 237 | port hawkesbury
# Processing Record 238 | inirida
# Processing Record 239 | pishva
# Processing Record 240 | qaqortoq
# Processing Record 241 | nishihara
# Processing Record 242 | hilo
# Processing Record 243 | nantucket
# Processing Record 244 | hamilton
# Processing Record 245 | hailar
# Processing Record 246 | north platte
# Processing Record 247 | salalah
# Processing Record 248 | krasnovishersk
# Processing Record 249 | katsuura
# Processing Record 250 | ushtobe
# Processing Record 251 | sur
# Processing Record 252 | port-cartier
# Processing Record 253 | cangzhou
# Processing Record 254 | liuhe
# City Not Found. Skipping...
# Processing Record 255 | mutoko
# Processing Record 256 | talnakh
# Processing Record 257 | esperance
# Processing Record 258 | broome
# Processing Record 259 | eureka
# Processing Record 260 | severo-kurilsk
# Processing Record 261 | soderhamn
# Processing Record 262 | atar
# Processing Record 263 | pathein
# Processing Record 264 | conselheiro pena
# City Not Found. Skipping...
# Processing Record 265 | verkhnevilyuysk
# Processing Record 266 | nhulunbuy
# Processing Record 267 | petropavlovka
# Processing Record 268 | payakumbuh
# Processing Record 269 | sao joao de pirabas
# Processing Record 270 | kidal
# City Not Found. Skipping...
# Processing Record 271 | nome
# Processing Record 272 | tilichiki
# Processing Record 273 | tual
# Processing Record 274 | ponta do sol
# Processing Record 275 | dwarka
# Processing Record 276 | waingapu
# Processing Record 277 | hofn
# Processing Record 278 | quatre cocos
# Processing Record 279 | biggar
# Processing Record 280 | arlit
# Processing Record 281 | lagoa
# Processing Record 282 | buala
# Processing Record 283 | minot
# Processing Record 284 | dingle
# City Not Found. Skipping...
# Processing Record 285 | wonthaggi
# City Not Found. Skipping...
# Processing Record 286 | sioux lookout
# Processing Record 287 | saint anthony
# Processing Record 288 | rapid valley
# Processing Record 289 | jalu
# Processing Record 290 | elizabeth city
# Processing Record 291 | namatanai
# Processing Record 292 | itupiranga
# Processing Record 293 | langsa
# Processing Record 294 | hadsund
# Processing Record 295 | ixtapa
# Processing Record 296 | samarai
# Processing Record 297 | fort nelson
# Processing Record 298 | baoshan
# Processing Record 299 | westport
# Processing Record 300 | henties bay
# Processing Record 301 | mobaye
# Processing Record 302 | launceston
# Processing Record 303 | ahipara
# City Not Found. Skipping...
# Processing Record 304 | kawalu
# Processing Record 305 | sovetskiy
# Processing Record 306 | port hueneme
# Processing Record 307 | anadyr
# Processing Record 308 | isangel
# Processing Record 309 | atambua
# Processing Record 310 | kahului
# Processing Record 311 | antalaha
# Processing Record 312 | besikduzu
# Processing Record 313 | maningrida
# Processing Record 314 | maues
# City Not Found. Skipping...
# Processing Record 315 | port keats
# Processing Record 316 | whitefish bay
# Processing Record 317 | vostok
# Processing Record 318 | sambava
# Processing Record 319 | tapes
# Processing Record 320 | petropavlovsk-kamchatskiy
# Processing Record 321 | kavaratti
# City Not Found. Skipping...
# Processing Record 322 | poptun
# Processing Record 323 | nizhnevartovsk
# Processing Record 324 | upernavik
# Processing Record 325 | mountain home
# Processing Record 326 | hami
# City Not Found. Skipping...
# Processing Record 327 | khilok
# Processing Record 328 | marzuq
# Processing Record 329 | lieksa
# Processing Record 330 | goiatuba
# Processing Record 331 | madruga
# Processing Record 332 | basugaon
# Processing Record 333 | visnes
# Processing Record 334 | camabatela
# Processing Record 335 | raglan
# Processing Record 336 | mugur-aksy
# Processing Record 337 | egvekinot
# Processing Record 338 | dicabisagan
# Processing Record 339 | cabo san lucas
# City Not Found. Skipping...
# Processing Record 340 | marsh harbour
# Processing Record 341 | havre-saint-pierre
# Processing Record 342 | sola
# Processing Record 343 | kuandian
# Processing Record 344 | costinesti
# Processing Record 345 | cervo
# Processing Record 346 | tokonou
# Processing Record 347 | carballo
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-ef0dccd8eaba> in <module>
#      18
#      19 for city in cities:
# ---> 20     response = requests.get(query_url + city).json()
#      21
#      22     if response ["cod"] == '404':
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
# Create dataframe
weather_df = pd.DataFrame({
    "City": city_names,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": long,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
})

# Display the dataframe
weather_data.count()
# Out:
# City          347
# Cloudiness    347
# Country       347
# Date          347
# Humidity      347
# Lat           347
# Lng           347
# Max Temp      347
# Wind Speed    347
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city data in a csv
weather_df.to_csv("cities.csv")

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0      Penzance          75      GB  1573942635       100     50.12
# 1        Evensk          68      RU  1573942754        76     61.92
# 2   Port Alfred          13      ZA  1573942754        94    -33.59
# 3  Chincha Alta          23      PE  1573942754        30    -13.42
# 4        Borcea          90      RO  1573942754        93     44.33
#
#    Longitude  Max Temp  Wind Speed
# 0      -5.53     10.00        1.50
# 1     159.24    -13.57        5.86
# 2      26.89     18.89        0.45
# 3     -76.13     22.00        8.70
# 4      27.73     14.00        4.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for latitude and max temperature
plt.scatter(weather_df["Latitude"], weather_df["Max Temp"], marker = 'o', facecolors='blue', edgecolors = 'black')

plt.title("Temperature (F) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid(True)

# Save image 
plt.savefig("Temp (F) vs. Lat.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], marker="o", facecolors='blue', edgecolors = 'black')

# Incorporate the other graph properties
plt.title("Humidity (%) vs. Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humi_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], marker="o", facecolors='blue', edgecolors = 'black')

# Incorporate the other graph properties
plt.title("Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloud_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], marker="o", facecolors='blue', edgecolors = 'black')

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_vs_Lat.png")

# Show plot
plt.show()
